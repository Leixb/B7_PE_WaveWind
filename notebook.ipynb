# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nazare = pd.read_pickle('data/Nazare.pkl')
jaws = pd.read_pickle('data/Jaws.pkl')

# %%
nazare = nazare[~nazare.index.duplicated(keep='first')]
jaws = jaws[~jaws.index.duplicated(keep='first')]

# %%
nazare.describe()
# Out:
#                Wave          Wind
# count  34456.000000  34980.000000
# mean       2.413594      8.642167
# std        1.207411      4.517112
# min        0.000000      0.000000
# 25%        1.600000      5.000000
# 50%        2.100000      8.000000
# 75%        3.000000     11.000000
# max       11.400000     38.000000

# %%
nazare.describe()
# Out:
#               Wave         Wind
# count  1634.000000  1643.000000
# mean      4.183354    13.037127
# std       2.131662     7.563565
# min       0.000000     0.000000
# 25%       2.500000     7.000000
# 50%       4.050000    13.000000
# 75%       5.700000    19.000000
# max      11.400000    38.000000

# %%
jaws.describe()
# Out:
#                Wave          Wind
# count  26127.000000  26679.000000
# mean       2.047005     11.472282
# std        0.629170      4.431397
# min        0.000000      0.000000
# 25%        1.600000      8.000000
# 50%        1.900000     12.000000
# 75%        2.400000     15.000000
# max        5.900000     32.000000

# %%
nazare.plot(y='Wind', style='.')
nazare.plot(y='Wave', style='.')

# %%
jaws.plot(y='Wind', style='.')
jaws.plot(y='Wave', style='.')

# %%
nazare.plot.scatter(x='Wind', y='Wave', style='.')
jaws.plot.scatter(x='Wind', y='Wave', style='.')
